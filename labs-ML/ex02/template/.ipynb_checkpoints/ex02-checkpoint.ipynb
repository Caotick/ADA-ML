# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
import datetime
from helpers import *

height, weight, gender = load_data(sub_sample=False, add_outlier=False)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)

# %%
y.shape, tx.shape
# Out:
# ((10000,), (10000, 2))

# %% [markdown]
# # 1 Computing the Cost Function

# %% [markdown]
# Fill in the `compute_loss` function below:
# <a id='compute_loss'></a>

# %%
def compute_loss(y, tx, w, mae=False):
    """Calculate the loss.

    You can calculate the loss using mse or mae.
    """
    loss = 0
    txw = np.dot(tx, w)
    if(not mae) :
        for i in range(y.shape[0]) :
            loss += (y[i] - txw[i])**2
    else :
        e = np.absolute(y - txw)
        for i in range(y.shape[0]) :
            loss += e[i]
    return loss / (2*y.shape[0])

print(compute_loss(y, tx, np.transpose(np.array([1, 2]))))
# Out:
# 2776.19751894895

# %% [markdown]
# # 2 Grid Search
#
# Fill in the function `grid_search()` below:

# %%
def grid_search(y, tx, w0, w1):
    """Algorithm for grid search."""
    losses = np.zeros((len(w0), len(w1)))
    
    for i in range(len(w0)) :
        for j in range(len(w1)) :
            losses[i][j] = compute_loss(y, tx, np.transpose(np.array([w0[i], w1[j]])))
    
    return losses

# %% [markdown]
# Let us play with the grid search demo now!

# %%
from grid_search import generate_w, get_best_parameters
from plots import grid_visualization

# Generate the grid of parameters to be swept
grid_w0, grid_w1 = generate_w(num_intervals=20)

# Start the grid search
start_time = datetime.datetime.now()
grid_losses = grid_search(y, tx, grid_w0, grid_w1)

# Select the best combinaison
loss_star, w0_star, w1_star = get_best_parameters(grid_w0, grid_w1, grid_losses)
end_time = datetime.datetime.now()
execution_time = (end_time - start_time).total_seconds()

# Print the results
print("Grid Search: loss*={l}, w0*={w0}, w1*={w1}, execution time={t:.3f} seconds".format(
      l=loss_star, w0=w0_star, w1=w1_star, t=execution_time))

# Plot the results
fig = grid_visualization(grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight)
fig.set_size_inches(10.0,6.0)
fig.savefig("grid_plot")  # Optional saving
# Out:
# Grid Search: loss*=31.058026621448523, w0*=73.68421052631578, w1*=7.89473684210526, execution time=5.168 seconds

# %% [markdown]
# # 3 Gradient Descent

# %% [markdown]
# Again, please fill in the functions `compute_gradient` below:

# %%
def compute_gradient(y, tx, w):
    """Compute the gradient."""
    grad = np.zeros(w.shape)
    twx = np.dot(tx, w)
    e = y - twx
    for i in range(w.shape[0]) :
        for j in range(tx.shape[0]) :
            grad[i] += e[j] * tx[j][i]
    return (-1) * grad / y.shape[0]

print(np.linalg.norm(compute_gradient(y, tx, np.transpose(np.array([100, 20])))))
print(np.linalg.norm(compute_gradient(y, tx, np.transpose(np.array([50, 10])))))
# Out:
# 27.49052112929253
# 23.552392678247706

# %% [markdown]
# Please fill in the functions `gradient_descent` below:

# %%
def gradient_descent(y, tx, initial_w, max_iters, gamma):
    """Gradient descent algorithm."""
    # Define parameters to store w and loss
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        
        grad = compute_gradient(y, tx, w)
        loss = compute_loss(y, tx, w)
        
        w = w - gamma*grad
        
        # store w and loss
        ws.append(w)
        losses.append(loss)
        print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))

    return losses, ws

# %% [markdown]
# Test your gradient descent function through gradient descent demo shown below:

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=2792.2367127591647, w0=51.305745401473324, w1=9.435798704492441
# Gradient Descent(1/49): loss=265.30246210896706, w0=66.69746902191562, w1=12.266538315840048
# Gradient Descent(2/49): loss=37.8783795504418, w0=71.31498610804832, w1=13.115760199244336
# Gradient Descent(3/49): loss=17.410212120174513, w0=72.70024123388814, w1=13.370526764265632
# Gradient Descent(4/49): loss=15.568077051450455, w0=73.11581777164008, w1=13.446956733772023
# Gradient Descent(5/49): loss=15.402284895265337, w0=73.24049073296567, w1=13.469885724623941
# Gradient Descent(6/49): loss=15.387363601208571, w0=73.27789262136332, w1=13.476764421879516
# Gradient Descent(7/49): loss=15.386020684743487, w0=73.28911318788263, w1=13.478828031056189
# Gradient Descent(8/49): loss=15.385899822261706, w0=73.29247935783842, w1=13.47944711380919
# Gradient Descent(9/49): loss=15.385888944638241, w0=73.29348920882516, w1=13.47963283863509
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact

def plot_figure_grad(n_iter):
    fig = gradient_descent_visualization(
        gradient_losses, gradient_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure_grad, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# <function __main__.plot_figure_grad(n_iter)>

# %% [markdown]
# # 4 Stochastic gradient descent

# %%
def compute_stoch_gradient(y, tx, w, batch_size):
    """Compute a stochastic gradient from just few examples n and their corresponding y_n labels."""
    sto_grad = np.zeros(w.shape)
    nb_grad = 0
    for minibatch_y, minibatch_tx in batch_iter(y, tx, batch_size) :
        sto_grad += compute_gradient(minibatch_y, minibatch_tx, w)
        nb_grad += 1
    return sto_grad / nb_grad
    


def stochastic_gradient_descent(
        y, tx, initial_w, batch_size, max_iters, gamma):
    """Stochastic gradient descent algorithm."""
    ws = [initial_w]
    losses = []
    w = initial_w
    
    for n_iter in range(max_iters) :
        
        sto_grad = compute_stoch_gradient(y, tx, w, batch_size)
        
        w = w - gamma * sto_grad
        loss = compute_loss(y, tx, w)
        
        ws.append(w)
        losses.append(loss)
        print("Stochastic Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
        
    return losses, ws

# %%
# from stochastic_gradient_descent import *

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start SGD.
start_time = datetime.datetime.now()
sgd_losses, sgd_ws = stochastic_gradient_descent(
    y, tx, w_initial, batch_size, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Stochastic Gradient Descent(0/49): loss=222.6907305488763, w0=53.0662574622437, w1=15.8145084909487
# Stochastic Gradient Descent(1/49): loss=80.77857231211478, w0=68.87297387629089, w1=24.02677774034433
# Stochastic Gradient Descent(2/49): loss=22.211117867848625, w0=73.53399026476941, w1=17.16655759410544
# Stochastic Gradient Descent(3/49): loss=15.700784666765216, w0=72.92888919418975, w1=14.18437167534357
# Stochastic Gradient Descent(4/49): loss=15.480390656693393, w0=72.90905424229621, w1=13.681906359694063
# Stochastic Gradient Descent(5/49): loss=17.291193270368264, w0=74.95749642678147, w1=14.501050252090009
# Stochastic Gradient Descent(6/49): loss=15.98179174234352, w0=74.20406849333541, w1=14.082573207912189
# Stochastic Gradient Descent(7/49): loss=15.843984019555297, w0=74.02633398973924, w1=12.86346168908961
# Stochastic Gradient Descent(8/49): loss=15.573603426157852, w0=72.82119329789089, w1=13.86953122220793
# ...

# %%
# Time Visualization
from ipywidgets import IntSlider, interact
def plot_figure_sto(n_iter):
    fig = gradient_descent_visualization(
        sgd_losses, sgd_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

interact(plot_figure_sto, n_iter=IntSlider(min=1, max=len(gradient_ws)))
# Out:
# <function __main__.plot_figure_sto(n_iter)>

# %% [markdown]
# # 5 Effect of Outliers

# %% [markdown]
# ### Exercise 5

# %%
height, weight, gender = load_data(sub_sample=True, add_outlier=True)
x, mean_x, std_x = standardize(height)
y, tx = build_model_data(x, weight)

plt.scatter(tx[:,1], weight)

# %%
# from gradient_descent import *
from plots import gradient_descent_visualization

# Define the parameters of the algorithm.
max_iters = 50
gamma = 0.7

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
gradient_losses, gradient_ws = gradient_descent(y, tx, w_initial, max_iters, gamma)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Gradient Descent(0/49): loss=2869.8351145358542, w0=51.84746409844842, w1=7.724426406192425
# Gradient Descent(1/49): loss=318.2821247015965, w0=67.40170332798297, w1=10.041754328050116
# Gradient Descent(2/49): loss=88.64235561651282, w0=72.06797509684336, w1=10.736952704607413
# Gradient Descent(3/49): loss=67.9747763988552, w0=73.46785662750146, w1=10.9455122175746
# Gradient Descent(4/49): loss=66.11469426926604, w0=73.88782108669889, w1=11.00808007146475
# Gradient Descent(5/49): loss=65.94728687760302, w0=74.01381042445813, w1=11.026850427631798
# Gradient Descent(6/49): loss=65.93222021235334, w0=74.0516072257859, w1=11.032481534481912
# Gradient Descent(7/49): loss=65.93086421248086, w0=74.06294626618423, w1=11.034170866536945
# Gradient Descent(8/49): loss=65.93074217249234, w0=74.06634797830372, w1=11.034677666153454
# Gradient Descent(9/49): loss=65.93073118889339, w0=74.06736849193958, w1=11.034829706038408
# ...

# %%
plot_figure_grad(50)

# %% [markdown]
# # 6 Subgradient Descent

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Modify the function `compute_loss(y, tx, w)` for the Mean Absolute Error cost function [here](#compute_loss)

# %%
def subgradient_mae(y, tx, w) :
    txw = np.dot(tx, w)
    e = np.sign(y - txw)
    sub_grad = np.dot(tx.T, e)
    return (-1) * sub_grad / (y.shape[0])

def subgradient_descent(y, tx, initial_w, max_iters, gamma) :
    ws = [initial_w]
    losses = []
    w = initial_w
    
    for n_iter in range(max_iters) :
        sub = subgradient_mae(y, tx, w)
        
        loss = compute_loss(y, tx, w, True)
        w = w - gamma * sub
        
        ws.append(w)
        losses.append(loss)
        print("Subgradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
        
    return losses, ws

# %%
max_iters = 50
gamma1 = 2

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
sub_losses, sub_ws = subgradient_descent(y, tx, w_initial, max_iters, gamma1)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Subgradient Descent(0/49): loss=37.03390292746316, w0=2.0, w1=1.7455783793116322e-15
# Subgradient Descent(1/49): loss=36.03390292746316, w0=4.0, w1=3.4911567586232645e-15
# Subgradient Descent(2/49): loss=35.03390292746317, w0=6.0, w1=5.236735137934897e-15
# Subgradient Descent(3/49): loss=34.03390292746317, w0=8.0, w1=6.982313517246529e-15
# Subgradient Descent(4/49): loss=33.03390292746315, w0=10.0, w1=8.72789189655816e-15
# Subgradient Descent(5/49): loss=32.03390292746315, w0=12.0, w1=1.0473470275869793e-14
# Subgradient Descent(6/49): loss=31.033902927463156, w0=14.0, w1=1.2219048655181424e-14
# Subgradient Descent(7/49): loss=30.033902927463153, w0=16.0, w1=1.3964627034493056e-14
# Subgradient Descent(8/49): loss=29.03390292746316, w0=18.0, w1=1.5710205413804688e-14
# Subgradient Descent(9/49): loss=28.033902927463153, w0=20.0, w1=1.745578379311632e-14
# Subgradient Descent(10/49): loss=27.03390292746316, w0=22.0, w1=1.9201362172427955e-14
# ...

# %%
def plot_figure_sub(n_iter):
    fig = gradient_descent_visualization(
        sub_losses, sub_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)

# %%
plot_figure_grad(50)
plot_figure_sto(50)
plot_figure_sub(50)

# %%
def sto_sub(y, tx, w, batch_size) :
    sto_sub = np.zeros(w.shape)
    nb_grad = 0
    for minibatch_y, minibatch_tx in batch_iter(y, tx, batch_size) :
        sto_sub += subgradient_mae(minibatch_y, minibatch_tx, w)
        nb_grad += 1
    return sto_sub / nb_grad   

def stochastic_subgradient_descent(y, tx, initial_w, batch_size, max_iters, gamma):

    ws = [initial_w]
    losses = []
    w = initial_w
    
    for n_iter in range(max_iters) :
        
        sub = sto_sub(y, tx, w, batch_size)
        
        w = w - gamma * sub
        loss = compute_loss(y, tx, w)
        
        ws.append(w)
        losses.append(loss)
        print("Stochastic Subgradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
              bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
        
    return losses, ws

# %%
max_iters = 50
gamma1 = 2
batch_size = 1

# Initialization
w_initial = np.array([0, 0])

# Start gradient descent.
start_time = datetime.datetime.now()
sub_sto_losses, sub_sto_ws = stochastic_subgradient_descent(y, tx, w_initial, batch_size, max_iters, gamma1)
end_time = datetime.datetime.now()

# Print result
exection_time = (end_time - start_time).total_seconds()
print("Gradient Descent: execution time={t:.3f} seconds".format(t=exection_time))
# Out:
# Stochastic Subgradient Descent(0/49): loss=2722.529573230616, w0=2.0, w1=0.10653517605105634
# Stochastic Subgradient Descent(1/49): loss=2597.203568482713, w0=4.0, w1=-1.3363726291612927
# Stochastic Subgradient Descent(2/49): loss=2489.721718450071, w0=6.0, w1=-3.6059993277063795
# Stochastic Subgradient Descent(3/49): loss=2311.882735559562, w0=8.0, w1=-0.23227161142096264
# Stochastic Subgradient Descent(4/49): loss=2189.8458695331524, w0=10.0, w1=-0.9294911105899651
# Stochastic Subgradient Descent(5/49): loss=2031.4541490803615, w0=12.0, w1=2.167295737099469
# Stochastic Subgradient Descent(6/49): loss=1914.6794510462378, w0=14.0, w1=1.582057108884546
# Stochastic Subgradient Descent(7/49): loss=1791.8567206109715, w0=16.0, w1=2.091634598541159
# Stochastic Subgradient Descent(8/49): loss=1708.2659051562896, w0=18.0, w1=-0.8424573945803657
# Stochastic Subgradient Descent(9/49): loss=1633.7819493241823, w0=20.0, w1=-3.538190204686424
# ...

# %%
def plot_figure_sub_sto(n_iter):
    fig = gradient_descent_visualization(
        sub_sto_losses, sub_sto_ws, grid_losses, grid_w0, grid_w1, mean_x, std_x, height, weight, n_iter)
    fig.set_size_inches(10.0, 6.0)
plot_figure_sub(50)
plot_figure_sub_sto(50)
